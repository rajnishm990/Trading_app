# %%
import setup 
setup.init_django()

# %%
import market.tasks as tasks

# %%
from market.models import *

# %%
qs = Company.objects.filter(active=True)

# %%
qs
# Out:
# <QuerySet [<Company: Company object (1)>, <Company: Company object (2)>]>

# %%
qs.count()
# Out:
# 2

# %%
obj, created = Company.objects.get_or_create(name='Meta', ticker='META')
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# File ~\OneDrive\Desktop\stock_trading_bot\.venv\Lib\site-packages\django\db\models\query.py:948, in QuerySet.get_or_create(self, defaults, **kwargs)
#     947 try:
# --> 948     return self.get(**kwargs), False
#     949 except self.model.DoesNotExist:
#
# File ~\OneDrive\Desktop\stock_trading_bot\.venv\Lib\site-packages\django\db\models\query.py:649, in QuerySet.get(self, *args, **kwargs)
#     648 if not num:
# --> 649     raise self.model.DoesNotExist(
#     650         "%s matching query does not exist." % self.model._meta.object_name
#     651     )
#     652 raise self.model.MultipleObjectsReturned(
#     653     "get() returned more than one %s -- it returned %s!"
#     654     % (
#    (...)    657     )
#     658 )
#
# DoesNotExist: Company matching query does not exist.
#
# ...

# %%
stocks = StockQuote.objects.all()
stocks.count()
# Out:
# 0

# %%
start_from_strach = True
if start_from_strach:
    stocks.delete()

# %%
tasks.sync_stock_data.delay()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Desktop\stock_trading_bot\.venv\Lib\site-packages\kombu\utils\functional.py:32, in ChannelPromise.__call__(self)
#      31 try:
# ---> 32     return self.__value__
#      33 except AttributeError:
#
# AttributeError: 'ChannelPromise' object has no attribute '__value__'
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\OneDrive\Desktop\stock_trading_bot\.venv\Lib\site-packages\kombu\connection.py:472, in Connection._reraise_as_library_errors(self, ConnectionError, ChannelError)
#     471 try:
# --> 472     yield
#     473 except (ConnectionError, ChannelError):
#
# ...

# %%
StockQuote.objects.all().count()
# Out:
# 0
